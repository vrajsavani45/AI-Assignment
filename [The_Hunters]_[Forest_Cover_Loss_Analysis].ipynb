# %% [markdown]
# <a href="https://colab.research.google.com/github/vrajsavani45/AI-Assignment/blob/main/%5BThe_Hunters%5D_%5BForest_Cover_Loss_Analysis%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Deforestation Analysis in India (2012–2024) in km sq. :

import matplotlib.pyplot as plt
import pandas as pd


data = {
'years' : [2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],
'total_forest_cover_million' : [70120,70230,70350,70450,70560,70610,70700,70750,70810,70900,70950,71000,71100],
'deforestation' : [200,180,150,200,250,220,180,200,150,180,200,220,180]
};

df = pd.DataFrame(data)
print(df)

plt.plot(years, deforestation, "o--g")
plt.title("Deforestation Analysis in India (2012–2024) in km sq.")
plt.xlabel("years")
plt.ylabel("deforestation")
plt.show()
# Out:
#     years  deforestation  total_forest_cover_million
# 0    2012            200                       70120
# 1    2013            180                       70230
# 2    2014            150                       70350
# 3    2015            200                       70450
# 4    2016            250                       70560
# 5    2017            220                       70610
# 6    2018            180                       70700
# 7    2019            200                       70750
# 8    2020            150                       70810
# 9    2021            180                       70900
# 10   2022            200                       70950
# 11   2023            220                       71000
# 12   2024            180                       71100
